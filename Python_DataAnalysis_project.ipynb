# %% [markdown]
# # ABC COMPANY EMPLOYEES DATA ANALYSIS

# %% [markdown]
# ### IMPORT MODULES

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### READ DATASET

# %%
df=pd.read_csv("myexcel.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180  \
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### DATA PREPROCESSING

# %% [markdown]
# #### The column 'Height' has incorrect data, so replace the data of 'Height' column with any random numbers between 150 and 180.

# %%
import random

height=[]
for i in range(0,458):
    ht=random.randint(150,180)
    height.append(ht)
df_height=pd.DataFrame(height)
df['Height']=df_height
df1=df
df1
# Out:
#               Name            Team  Number Position  Age  Height  Weight
# 0    Avery Bradley  Boston Celtics       0       PG   25     157     180  \
# 1      Jae Crowder  Boston Celtics      99       SF   25     171     235
# 2     John Holland  Boston Celtics      30       SG   27     155     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     172     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     178     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     164     203
# 454      Raul Neto       Utah Jazz      25       PG   24     152     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     175     256
# 456    Jeff Withey       Utah Jazz      24        C   26     176     231
# 457       Priyanka       Utah Jazz      34        C   25     156     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#saving the dataframe
df1.to_csv("team.csv")

# %%
df1.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight
# 0  Avery Bradley  Boston Celtics       0       PG   25     157     180  \
# 1    Jae Crowder  Boston Celtics      99       SF   25     171     235
# 2   John Holland  Boston Celtics      30       SG   27     155     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     172     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     178     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df1.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College
# 453  Shelvin Mack  Utah Jazz       8       PG   26     164     203  Butler  \
# 454     Raul Neto  Utah Jazz      25       PG   24     152     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26     175     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     176     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25     156     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %%
df1.describe()
# Out:
#            Number         Age      Height      Weight        Salary
# count  458.000000  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  164.903930  221.543668  4.833970e+06
# std     15.966837    4.400128    9.083345   26.343200  5.226620e+06
# min      0.000000   19.000000  150.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  157.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  165.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  172.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  180.000000  307.000000  2.500000e+07

# %% [markdown]
# #### Check If Any Value is NaN in dataframe

# %%
df1.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %% [markdown]
# #### Replace NaN values with zeros for entire DataFrame

# %%
df1 = df1.fillna(0)
df1
# Out:
#               Name            Team  Number Position  Age  Height  Weight
# 0    Avery Bradley  Boston Celtics       0       PG   25     157     180  \
# 1      Jae Crowder  Boston Celtics      99       SF   25     171     235
# 2     John Holland  Boston Celtics      30       SG   27     155     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     172     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     178     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     164     203
# 454      Raul Neto       Utah Jazz      25       PG   24     152     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     175     256
# 456    Jeff Withey       Utah Jazz      24        C   26     176     231
# 457       Priyanka       Utah Jazz      34        C   25     156     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# Check If Any Value is NaN in dataframe

# %%
df1.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df1.shape
# Out:
# (458, 9)

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
df1.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height        int64
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %% [markdown]
# ### DATA ANALYSIS

# %% [markdown]
# #### 1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
#number of employees in each Team

counts = df1["Team"].value_counts()
print("No of employees in each team:\n",counts)
# Out:
# No of employees in each team:
#  Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
#Visualization

plt.figure(figsize=(60,30),dpi=100)
x=counts.index
y=counts.values
plt.bar(x, y, color =['red','blue'],width=.2)
plt.xticks(fontsize=35)
plt.xticks(rotation=45)
plt.yticks(fontsize=35)
plt.title("Number of Employees in each team",size=50)
plt.xlabel("Team",size=50)
plt.ylabel("Number of Employees",size=50)
plt.show()

# %%
#percentage splitting of employees with respect to the total employees.

percentage = df1["Team"].value_counts(normalize=True).mul(100).round(1)
print("The percentage splitting of employees with respect to the total employees:\n",percentage)
# Out:
# The percentage splitting of employees with respect to the total employees:
#  Team
# New Orleans Pelicans      4.1
# Memphis Grizzlies         3.9
# Utah Jazz                 3.5
# New York Knicks           3.5
# Milwaukee Bucks           3.5
# Brooklyn Nets             3.3
# Portland Trail Blazers    3.3
# Oklahoma City Thunder     3.3
# Denver Nuggets            3.3
# Washington Wizards        3.3
# Miami Heat                3.3
# Charlotte Hornets         3.3
# Atlanta Hawks             3.3
# San Antonio Spurs         3.3
# Houston Rockets           3.3
# Boston Celtics            3.3
# Indiana Pacers            3.3
# Detroit Pistons           3.3
# Cleveland Cavaliers       3.3
# Chicago Bulls             3.3
# Sacramento Kings          3.3
# Phoenix Suns              3.3
# Los Angeles Lakers        3.3
# Los Angeles Clippers      3.3
# Golden State Warriors     3.3
# Toronto Raptors           3.3
# Philadelphia 76ers        3.3
# Dallas Mavericks          3.3
# ...

# %%
#visualization

plt.figure(figsize=(60,30),dpi=100)
x=percentage.index
y=percentage.values
plt.bar(x, y, color =['red','blue'],width=.2)
plt.xticks(fontsize=35)
plt.xticks(rotation=45)
plt.yticks(fontsize=35)
plt.title("Percentage split of Employees by team",size=50)
plt.xlabel("Team",size=50)
plt.ylabel("Percentage",size=50)
plt.show()

# %% [markdown]
# #### 2.Segregate the employees w.r.t different positions.

# %%
group_data = df1.groupby(['Position','Name']).sum()
group_data
# Out:
#                                           Team  Number  Age  Height  Weight
# Position Name
# C        Al Horford              Atlanta Hawks      15   30     172     245  \
#          Al Jefferson        Charlotte Hornets      25   31     151     289
#          Alan Williams            Phoenix Suns      15   23     172     260
#          Alex Len                 Phoenix Suns      21   22     159     260
#          Alexis Ajinca    New Orleans Pelicans      42   28     157     248
# ...                                        ...     ...  ...     ...     ...
# SG       Tyreke Evans     New Orleans Pelicans       1   26     164     220
#          Victor Oladipo          Orlando Magic       5   24     165     210
#          Vince Carter        Memphis Grizzlies      15   39     174     220
#          Wayne Ellington         Brooklyn Nets      21   28     158     200
#          Wesley Matthews      Dallas Mavericks      23   29     166     220
#
# ...

# %%
#Number of employees in each position

position = df1["Position"].value_counts()
print("No of employees with respect to position are\n",position)
# Out:
# No of employees with respect to position are
#  Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
#Visualization

plt.bar(position.index,position.values,color='red')
plt.xlabel("Position")
plt.ylabel("Number of employees")
plt.title("Employee Position Distribution")
# Out:
# Text(0.5, 1.0, 'Employee Position Distribution')

# %% [markdown]
# #### 3.Find from which age group most of the employees belong to.

# %%
age = df1["Age"].value_counts()
age
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
age_group=age.head(1).index
print("Most of the employees belong to age group",age_group[0])
# Out:
# Most of the employees belong to age group 24

# %%
#Visualization

plt.figure(figsize=(5,5),dpi=100)
x=age.index
y=age.values
plt.bar(x, y, color =['red','blue'],width=.4)
plt.title("Age Vs Employees")
plt.xlabel("Age")
plt.ylabel("Number of Employees")
plt.show()

# %% [markdown]
# #### 4.Find out under which team and position, spending in terms of salary is high

# %%
salary_sum=df1.groupby(['Team','Position'])['Salary'].sum()
print(salary_sum)
# Out:
# Team                Position
# Atlanta Hawks       C           22756250.0
#                     PF          23952268.0
#                     PG           9763400.0
#                     SF           6000000.0
#                     SG          10431032.0
#                                    ...
# Washington Wizards  C           24490429.0
#                     PF          11300000.0
#                     PG          18022415.0
#                     SF          11158800.0
#                     SG          11356992.0
# Name: Salary, Length: 149, dtype: float64

# %%
#team and position spending high salary

heighest_salary = salary_sum.idxmax()
print("highest salary is:",heighest_salary)
print("under {} team and {} position, spending in terms of salary is high".format (heighest_salary[0],heighest_salary[1]))
# Out:
# highest salary is: ('Los Angeles Lakers', 'SF')
# under Los Angeles Lakers team and SF position, spending in terms of salary is high

# %% [markdown]
# #### 5.Find if there is any correlation between age and salary , represent it visually.

# %%
correlation=df1['Age'].corr(df1["Salary"])
print("The correlation between age and salary is",correlation)

#Visualization

sns.scatterplot(data=df1,x='Age',y='Salary')
plt.title("correlation between age and salary")
plt.show()
# Out:
# The correlation between age and salary is 0.20500960284809364
